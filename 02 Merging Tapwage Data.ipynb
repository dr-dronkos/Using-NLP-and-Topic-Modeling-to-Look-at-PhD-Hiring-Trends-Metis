# %%
import pandas as pd
import re

# %%
df_1 = pd.read_pickle('batch_1_jds')
df_1.head()
# Out:
#                                                title  \
# 0             PhD Program & Lab Manager (Hybrid) job
# 1             PhD Program & Lab Manager (Hybrid) job
# 2  Assistant Professor - Clinical PhD Program - L...
# 3  Data Scientist / Statistician Intern (BS / MS ...
# 4                       PhD Scientist Internship job
#
#                           company         location        uid  \
# 0            Mass General Brigham  Charlestown, MA  48022361
# 1  Massachusetts General Hospital  Charlestown, MA  47983977
# 2                     Bertelsmann  Los Angeles, CA  48973936
# 3                        Lubrizol    Hazelwood, DE  39232138
# 4             Danaher Corporation      Madison, WI  49810371
#
#                                                 tags  \
# 0  [PhD, Masters Degree, Bachelor's Degree, Entry...
# 1  [PhD, Masters Degree, Bachelor's Degree, Entry...
# 2        [PhD, Fortune500, Media, Junior, Full-Time]
# 3  [PhD, Bachelor's Degree, Data Science, Program...
# ...

# %%
df_2 = pd.read_pickle('batch_2_jds')
df_2.head()
# Out:
#                                                title  \
# 0  Staff Research Scientist - Identity and Authen...
# 1  PostDoctoral Scholar - Robotic / Force Control...
# 2  Assistant Professor, Information Design and Da...
# 3     Research Scholar - Cancer Research Program job
# 4  Research Fellow / Day / 40 HRS / BWH Neurology...
#
#                              company     location        uid  \
# 0                               Visa  Atlanta, GA  48994948
# 1  University of California Berkeley     June, MO  48792544
# 2            Northeastern University   Boston, MA  47943028
# 3    Eastern Virginia Medical School  Norfolk, VA  47615956
# 4       Brigham and Women's Hospital   Boston, MA  47550874
#
#                                                 tags  \
# 0  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 1  [PhD, Mechanical Engineering, Postdoc, Univers...
# 2  [PhD, MFA, Bachelor's Degree, Universities, Da...
# 3         [PhD, Universities, Junior, Full-Time, MD]
# ...

# %%
df_3 = pd.read_pickle('batch_3_jds')
df_3.head()
# Out:
#                                                title                 company  \
# 0  Post Doctoral Fellow - Division of Digestive D...        Emory University
# 1                   Assistant Research Scientist job    Texas A&M University
# 2  Program Administrator (Academic Services Profe...  University of Colorado
# 3   Cross Domain Solutions (CDS) System Engineer job                 Peraton
# 4          Server Performance Architect - 136824 job                     AMD
#
#                  location        uid  \
# 0             Atlanta, GA  46138113
# 1     College Station, TX  46026714
# 2              Aurora, CO  45989129
# 3  Annapolis Junction, MD  45950924
# 4              Austin, TX  45935025
#
#                                                 tags  \
# 0         [PhD, Universities, Junior, Full-Time, MD]
# 1  [PhD, Universities, Junior, Programming, Data ...
# 2  [PhD, Bachelor's Degree, Universities, Event M...
# 3  [Senior, PhD, Bachelor's Degree, IT Services, ...
# ...

# %%
df_4 = pd.read_pickle('batch_4_jds')
df_4.head()
# Out:
#                                                title                  company  \
# 0    Research Lab Manager 1 - Mendillo Lab (New) job  Northwestern University
# 1                  Assistant Professor (Posting) job  Northwestern University
# 2  Senior Product Manager, Visa Direct Cross Bord...                     Visa
# 3  Senior Risk Manager, Regulatory & Risk Governa...                     Visa
# 4  Deloitte Risk & Financial Advisory Solution De...                 Deloitte
#
#        location        uid                                               tags  \
# 0   Chicago, IL  48594634   [PhD, Masters Degree, Bachelor's Degree, Unive...
# 1  Evanston, IL  48594600   [PhD, MFA, Masters Degree, Universities, Full-...
# 2     Miami, FL  48584235   [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 3   Atlanta, GA  48583939   [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 4    Denver, CO  38982822   [Consulting Firms, Auditors, Fortune500, Partn...
#
# ...

# %%
df_5 = pd.read_pickle('batch_5_jds')
df_5.head()
# Out:
#                                                title  \
# 0                              Applied Scientist job
# 1  Software Engineering Intern, DL Inference Depl...
# 2                PostDoctoral Research Scientist job
# 3                  Faculty. Instructor. Research job
# 4  PostDoctoral Researcher - Computational Flow M...
#
#                         company           location        uid  \
# 0                        Amazon        Seattle, WA  24130921
# 1                        NVIDIA    Santa Clara, CA  23554431
# 2           Columbia University  New York City, NY  24371884
# 3  The University of Pittsburgh     Pittsburgh, PA  21061346
# 4                          NREL         Golden, CO  19834346
#
#                                                 tags  \
# 0  [PhD, Masters Degree, Fortune500, Conglomerate...
# 1  [PhD, Masters Degree, Bachelor's Degree, Entry...
# 2            [PhD, Universities, Postdoc, Full-Time]
# 3  [PhD, Universities, Junior, Programming, Lectu...
# ...

# %%
df_6 = pd.read_pickle('batch_6_jds')
df_6.head()
# Out:
#                                               title  \
# 0                                Medical Writer job
# 1  Downstream Laboratory Associate Scientist II job
# 2                    Signal Processing Engineer job
# 3       PostDoctoral Scholar Research Associate job
# 4          TTU Post Doctoral Research Associate job
#
#                              company           location        uid  \
# 0                      Syneos Health  New York City, NY  47098421
# 1                        AstraZeneca      Frederick, MD  47079815
# 2                    General Atomics        Boulder, CO  46996084
# 3  University of Southern California    Los Angeles, CA  46966064
# 4              Texas Tech University        Lubbock, TX  46926714
#
#                                                 tags  \
# 0  [Senior, PhD, Pharma / Biotech, Healthcare, Wr...
# 1  [PhD, Bachelor's Degree, Pharma / Biotech, For...
# 2  [Senior, PhD, Masters Degree, Bachelor's Degre...
# ...

# %%
df_7 = pd.read_pickle('batch_7_jds')
df_7.head()
# Out:
#                                                title      company  \
# 0  PostDoctoral Research Fellow - Metabolic Disea...  Merck & Co.
# 1  Manager, Pharmacokinetics, Dynamics and Metabo...       Sanofi
# 2  Senior Development Consultant, Visa Rules Mana...         Visa
# 3              Senior Employee Relations Manager job         Visa
# 4             Director, Employee Resource Groups job         Visa
#
#                   location        uid  \
# 0  South San Francisco, CA  49581145
# 1            Cambridge, MA  49566104
# 2              Ashburn, VA  49213631
# 3               Austin, TX  49558503
# 4          Foster City, CA  49558496
#
#                                                 tags  \
# 0  [PhD, Pharma / Biotech, Fortune500, Publicly L...
# 1  [PhD, Pharma / Biotech, Healthcare, Junior, Pu...
# 2  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 3  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 4  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
#
# ...

# %%
df_8 = pd.read_pickle('batch_8_jds')
df_8.head()
# Out:
#                                                title  \
# 0  Director, Visa Business Solutions, Risk Busine...
# 1                   Senior Cybersecurity Analyst job
# 2  HPLC / MS Method Development Senior Scientist job
# 3                   Solution Management, Manager job
# 4                              Faculty Professor job
#
#                         company         location        uid  \
# 0                          Visa  Foster City, CA  48227471
# 1                          Visa  Foster City, CA  48227342
# 2                      Eurofins  Lake Forest, IL  48207528
# 3                          Visa  Foster City, CA  48136365
# 4  The University of Pittsburgh   Pittsburgh, PA  48133877
#
#                                                 tags  \
# 0  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 1  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# 2  [Senior, PhD, Bachelor's Degree, Pharma / Biot...
# 3  [MBA, PhD, Masters Degree, Bachelor's Degree, ...
# ...

# %%
df_9 = pd.read_pickle('batch_9_jds')
df_9.head()
# Out:
#                                                title  \
# 0  Assistant Professor, Associate Professor or Pr...
# 1                           PostDoctoral Scholar job
# 2                           PostDoctoral Scholar job
# 3                           PostDoctoral Scholar job
# 4  Associate Director of Diversity, Equity, and I...
#
#                               company       location        uid  \
# 0  Oregon Health & Science University  Beaverton, OR  45519755
# 1  Oregon Health & Science University   Portland, OR  45519722
# 2  Oregon Health & Science University   Portland, OR  45519279
# 3  Oregon Health & Science University   Portland, OR  45518604
# 4  Oregon Health & Science University   Portland, OR  45518074
#
#                                                 tags  \
# 0  [PhD, Universities, Hospitals, Healthcare, Jun...
# 1  [PhD, Universities, Hospitals, Healthcare, Pos...
# 2  [PhD, Universities, Hospitals, Healthcare, Jun...
# ...

# %%
df_10 = pd.read_pickle('batch_10_jds')
df_10.head()
# Out:
#                                                title  \
# 0  Assistant Professor, Associate Professor or Pr...
# 1                           PostDoctoral Scholar job
# 2                           PostDoctoral Scholar job
# 3                           PostDoctoral Scholar job
# 4  Associate Director of Diversity, Equity, and I...
#
#                               company       location        uid  \
# 0  Oregon Health & Science University  Beaverton, OR  45519755
# 1  Oregon Health & Science University   Portland, OR  45519722
# 2  Oregon Health & Science University   Portland, OR  45519279
# 3  Oregon Health & Science University   Portland, OR  45518604
# 4  Oregon Health & Science University   Portland, OR  45518074
#
#                                                 tags  \
# 0  [PhD, Universities, Hospitals, Healthcare, Jun...
# 1  [PhD, Universities, Hospitals, Healthcare, Pos...
# 2  [PhD, Universities, Hospitals, Healthcare, Jun...
# ...

# %%
## Concatenate data
df_all = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10], axis=0, ignore_index=True)
df_all.head()
# Out:
#                                                title  \
# 0             PhD Program & Lab Manager (Hybrid) job
# 1             PhD Program & Lab Manager (Hybrid) job
# 2  Assistant Professor - Clinical PhD Program - L...
# 3  Data Scientist / Statistician Intern (BS / MS ...
# 4                       PhD Scientist Internship job
#
#                           company         location        uid  \
# 0            Mass General Brigham  Charlestown, MA  48022361
# 1  Massachusetts General Hospital  Charlestown, MA  47983977
# 2                     Bertelsmann  Los Angeles, CA  48973936
# 3                        Lubrizol    Hazelwood, DE  39232138
# 4             Danaher Corporation      Madison, WI  49810371
#
#                                                 tags  \
# 0  [PhD, Masters Degree, Bachelor's Degree, Entry...
# 1  [PhD, Masters Degree, Bachelor's Degree, Entry...
# 2        [PhD, Fortune500, Media, Junior, Full-Time]
# 3  [PhD, Bachelor's Degree, Data Science, Program...
# ...

# %%
df_all.tail()
# Out:
#                                                   title              company  \
# 6870                         Senior Biostatistician job  Blueprint Medicines
# 6871        Program Master Scheduler / Risk Manager job          Rolls-Royce
# 6872  Regional Director, Medical Science Liaisons - ...  Blueprint Medicines
# 6873  Medical Science Liaison, Southeast (Rare Disea...  Blueprint Medicines
# 6874                 IFS Standard Cell Library Lead job                Intel
#
#               location        uid  \
# 6870     Cambridge, MA  49822029
# 6871  Indianapolis, IN  49821707
# 6872     Cambridge, MA  49821023
# 6873     Nashville, TN  49821017
# 6874     Hillsboro, OR  49820736
#
#                                                    tags  \
# 6870  [PhD, Pharma / Biotech, Healthcare, Publicly L...
# 6871  [PhD, Bachelor's Degree, Automotive, Risk Mana...
# 6872  [PhD, Pharma / Biotech, Healthcare, Biology, M...
# 6873  [PhD, Pharma / Biotech, Healthcare, Biology, J...
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6875 entries, 0 to 6874
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        6875 non-null   object
#  1   company      6875 non-null   object
#  2   location     6875 non-null   object
#  3   uid          6875 non-null   object
#  4   tags         6875 non-null   object
#  5   description  6875 non-null   object
#  6   bullets      6875 non-null   object
#  7   headers      6875 non-null   object
# dtypes: object(8)
# memory usage: 429.8+ KB

# %%
df_all.to_csv('tapwage_corpus_may_2022.csv', index=False)

# %%
## Pickle this dataframe!
df_all.to_pickle('all_tapwage_jds')
